# %% [markdown]
# # 07 - Dashboard development
#
# Streamlit or Dash app scaffolding for visualizing churn insights.

# %%
# Dashboard development scaffold
# This notebook is for notes and small preview code for dashboard development.
# The full interactive app runs from `dashboard/streamlit_app.py`.

print('Use dashboard/streamlit_app.py as the app entrypoint. Keep heavy training or cleaning out of this notebook.')
