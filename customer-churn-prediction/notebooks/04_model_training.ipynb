# %% [markdown]
# # 04 - Model training
#
# Train baseline models and save pipelines to `models/`.

# %%
# Model training scaffold
# Train baseline models and persist the best pipeline to models/
import pandas as pd
from src.feature_engineering import split_data
from src.model_training import train_and_select

# Use processed data
df = pd.read_csv('data/processed/telco_clean.csv')
X_train, X_test, y_train, y_test = split_data(df, target='Churn')

# train_and_select should build pipelines (preprocessor + estimator)
best_model = train_and_select(X_train, y_train, X_test, y_test)
print('Training complete. Best model saved to models/tuned_model.pkl')
