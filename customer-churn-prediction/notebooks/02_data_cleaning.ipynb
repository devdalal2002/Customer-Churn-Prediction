# %% [markdown]
# # 02 - Data cleaning
#
# Cleaning and imputation steps (create `TotalCharges_imputed`, idempotent fills, persist processed CSV).

# %%
# Data cleaning scaffold
# Idempotent cleaning: create TotalCharges_imputed and persist cleaned data
from src.data_preprocessing import build_and_save_cleaned
DATA_RAW = 'data/raw/Telco-Customer-Churn.csv'
DATA_INTERIM = 'data/interim/cleaned_churn.csv'

# This will load raw, run idempotent cleaning, and write interim file.
# It is safe to re-run.
build_and_save_cleaned(DATA_RAW, DATA_INTERIM)
print('Cleaned data written to', DATA_INTERIM)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Data cleaning scaffold
#       2 # Idempotent cleaning: create TotalCharges_imputed and persist cleaned data
# ----> 3 from src.data_preprocessing import build_and_save_cleaned
#       4 DATA_RAW = 'data/raw/Telco-Customer-Churn.csv'
#       5 DATA_INTERIM = 'data/interim/cleaned_churn.csv'
#
# ModuleNotFoundError: No module named 'src'
